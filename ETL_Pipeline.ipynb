# %%
# Install Necessary Packages
# !pip install pyarrow
# !pip install azure-storage-blob
# Out:
# Collecting pyarrow
#   Downloading pyarrow-17.0.0-cp310-cp310-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: numpy>=1.16.6 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from pyarrow) (1.23.3)
# Downloading pyarrow-17.0.0-cp310-cp310-win_amd64.whl (25.1 MB)
#    ---------------------------------------- 25.1/25.1 MB 1.9 MB/s eta 0:00:00
# Installing collected packages: pyarrow
# Successfully installed pyarrow-17.0.0
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.23.1-py3-none-any.whl.metadata (26 kB)
# Collecting azure-core>=1.30.0 (from azure-storage-blob)
#   Downloading azure_core-1.31.0-py3-none-any.whl.metadata (39 kB)
# Requirement already satisfied: cryptography>=2.1.4 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-storage-blob) (43.0.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-storage-blob) (4.12.2)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: requests>=2.21.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-core>=1.30.0->azure-storage-blob) (2.28.1)
# Requirement already satisfied: six>=1.11.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from azure-core>=1.30.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cryptography>=2.1.4->azure-storage-blob) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.10_qbz5n2kfra8p0\localcache\local-packages\python310\site-packages (from requests>=2.21.0->azure-core>=1.30.0->azure-storage-blob) (2022.9.24)
# Downloading azure_storage_blob-12.23.1-py3-none-any.whl (405 kB)
# Downloading azure_core-1.31.0-py3-none-any.whl (197 kB)
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.31.0 azure-storage-blob-12.23.1 isodate-0.7.2

# %%
#  Import the Necessary Libraries 

import pandas as pd
import os
import io
from azure.storage.blob import BlobServiceClient, BlobClient
from dotenv import load_dotenv

# %%
# Extracting the Data From Source 

Ziko_DF = pd.read_csv(r'ziko_logistics_data.csv')

Ziko_DF
# Out:
#       Transaction_ID                           Date  Customer_ID  Product_ID  \
# 0                200  2020-01-01 20:32:25.945945945         1086         536
# 1                321  2020-01-02 06:55:08.108108108         1078         523
# 2                989  2020-01-06 08:12:58.378378378         1077         535
# 3                682  2020-01-07 22:03:14.594594594         1027         546
# 4                484  2020-01-07 07:08:06.486486486         1052         556
# ...              ...                            ...          ...         ...
# 1000             250  2020-01-05 02:22:42.162162162         1095         533
# 1001             412  2020-01-07 11:27:34.054054054         1008         542
# 1002             816  2020-01-06 02:48:38.918918918         1060         511
# 1003             702  2020-01-09 08:38:55.135135135         1054         504
# 1004               4  2020-01-03 10:22:42.162162162         1018         545
#
#       Quantity  Unit_Price   Total_Cost  Discount_Rate Sales_Channel  \
# 0            3  120.436821  8265.374549           0.20        Online
# 1            6  475.724994  4047.850479            NaN      Reseller
# 2            3  146.400556          NaN           0.05        Direct
# 3            6   19.373194  8194.281993            NaN      Reseller
# 4            8  193.221313  8331.329249           0.20        Direct
# ...        ...         ...          ...            ...           ...
# 1000         5  490.760429  1138.724711            NaN      Reseller
# 1001         9  236.240910  1786.865600           0.10        Online
# 1002         6         NaN  6443.682500           0.20       Partner
# 1003         6         NaN  4814.744796            NaN        Online
# 1004         2  248.937627  1971.790456           0.20        Direct
#
#      Order_Priority  ...  Return_Reason   Payment_Type Taxable Region  \
# 0              High  ...     Wrong Item  Wire Transfer   False   West
# 1          Critical  ...        Damaged         PayPal    True  South
# 2          Critical  ...        Damaged         PayPal    True   West
# 3            Medium  ...     Wrong Item           Cash    True  South
# 4               Low  ...           Late           Cash   False  South
# ...             ...  ...            ...            ...     ...    ...
# 1000         Medium  ...        Damaged    Credit Card    True  South
# 1001         Medium  ...  Not Specified           Cash    True  South
# 1002         Medium  ...  Not Specified           Cash   False   West
# 1003         Medium  ...        Damaged           Cash    True   West
# 1004            Low  ...  Not Specified           Cash    True   East
#
#       Country Customer_Name   Customer_Phone               Customer_Email  \
# 0      Canada  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1      Mexico  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2      Canada  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3      Canada  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4      Mexico  Customer 484  +1-986-360-9109    customer.484.3@sample.com
# ...       ...           ...              ...                          ...
# 1000   Canada  Customer 250  +1-875-504-2878   customer.250.26@sample.com
# 1001      USA  Customer 412  +1-645-470-5077   customer.412.80@sample.com
# 1002   Mexico  Customer 816  +1-162-396-1771   customer.816.55@sample.com
# 1003   Canada  Customer 702  +1-130-713-1098   customer.702.30@sample.com
# 1004   Canada    Customer 4  +1-756-713-6966     customer.4.99@sample.com
#
#                      Customer_Address Product_List_Title
# 0         275 Second St, Phoenix, USA         Product 53
# 1         478 Third St, New York, USA         Product 33
# 2         843 Second St, Phoenix, USA          Product 6
# 3           153 Main St, Phoenix, USA         Product 68
# 4        264 Second St, New York, USA         Product 89
# ...                               ...                ...
# 1000        664 Main St, Chicago, USA         Product 16
# 1001       699 Third St, Houston, USA         Product 38
# 1002  453 Fourth St, Los Angeles, USA         Product 48
# 1003      438 Fourth St, Houston, USA         Product 38
# 1004       383 Park Ave, Houston, USA         Product 16
#
# [1005 rows x 25 columns]

# %%
# View Summary of DataFrame
Ziko_DF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         1005 non-null   int64
#  1   Date                   1005 non-null   object
#  2   Customer_ID            1005 non-null   int64
#  3   Product_ID             1005 non-null   int64
#  4   Quantity               1005 non-null   int64
#  5   Unit_Price             904 non-null    float64
#  6   Total_Cost             905 non-null    float64
#  7   Discount_Rate          714 non-null    float64
#  8   Sales_Channel          1005 non-null   object
#  9   Order_Priority         1005 non-null   object
#  10  Warehouse_Code         1005 non-null   object
#  11  Ship_Mode              1005 non-null   object
#  12  Delivery_Status        1005 non-null   object
#  13  Customer_Satisfaction  1005 non-null   object
#  14  Item_Returned          1005 non-null   bool
#  15  Return_Reason          904 non-null    object
#  16  Payment_Type           1005 non-null   object
#  17  Taxable                1005 non-null   bool
#  18  Region                 1005 non-null   object
#  19  Country                1005 non-null   object
#  20  Customer_Name          1005 non-null   object
#  21  Customer_Phone         1005 non-null   object
#  22  Customer_Email         1005 non-null   object
#  23  Customer_Address       1005 non-null   object
#  24  Product_List_Title     1005 non-null   object
# dtypes: bool(2), float64(3), int64(4), object(16)
# memory usage: 182.7+ KB

# %%
# View Name of Columns 

Ziko_DF.columns
# Out:
# Index(['Transaction_ID', 'Date', 'Customer_ID', 'Product_ID', 'Quantity',
#        'Unit_Price', 'Total_Cost', 'Discount_Rate', 'Sales_Channel',
#        'Order_Priority', 'Warehouse_Code', 'Ship_Mode', 'Delivery_Status',
#        'Customer_Satisfaction', 'Item_Returned', 'Return_Reason',
#        'Payment_Type', 'Taxable', 'Region', 'Country', 'Customer_Name',
#        'Customer_Phone', 'Customer_Email', 'Customer_Address',
#        'Product_List_Title'],
#       dtype='object')

# %%
# Data Cleaning and Transformation

# Create  a copy of the Data Frame
ZikoDF = Ziko_DF.copy()

# Fill the Missing Values
ZikoDF.fillna({ 
               'Unit_Price' : ZikoDF['Unit_Price'].mean(),
               'Total_Cost' : ZikoDF['Total_Cost'].mean(),
               'Discount_Rate' : 0.0,
               'Return_Reason' : 'Unknown'
               }, inplace = True)

# %%
ZikoDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1005 entries, 0 to 1004
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Transaction_ID         1005 non-null   int64
#  1   Date                   1005 non-null   object
#  2   Customer_ID            1005 non-null   int64
#  3   Product_ID             1005 non-null   int64
#  4   Quantity               1005 non-null   int64
#  5   Unit_Price             1005 non-null   float64
#  6   Total_Cost             1005 non-null   float64
#  7   Discount_Rate          1005 non-null   float64
#  8   Sales_Channel          1005 non-null   object
#  9   Order_Priority         1005 non-null   object
#  10  Warehouse_Code         1005 non-null   object
#  11  Ship_Mode              1005 non-null   object
#  12  Delivery_Status        1005 non-null   object
#  13  Customer_Satisfaction  1005 non-null   object
#  14  Item_Returned          1005 non-null   bool
#  15  Return_Reason          1005 non-null   object
#  16  Payment_Type           1005 non-null   object
#  17  Taxable                1005 non-null   bool
#  18  Region                 1005 non-null   object
#  19  Country                1005 non-null   object
#  20  Customer_Name          1005 non-null   object
#  21  Customer_Phone         1005 non-null   object
#  22  Customer_Email         1005 non-null   object
#  23  Customer_Address       1005 non-null   object
#  24  Product_List_Title     1005 non-null   object
# dtypes: bool(2), float64(3), int64(4), object(16)
# memory usage: 182.7+ KB

# %%
ZikoDF['Date'] = pd.to_datetime(ZikoDF['Date'])

ZikoDF
# Out:
#       Transaction_ID                          Date  Customer_ID  Product_ID  \
# 0                200 2020-01-01 20:32:25.945945945         1086         536
# 1                321 2020-01-02 06:55:08.108108108         1078         523
# 2                989 2020-01-06 08:12:58.378378378         1077         535
# 3                682 2020-01-07 22:03:14.594594594         1027         546
# 4                484 2020-01-07 07:08:06.486486486         1052         556
# ...              ...                           ...          ...         ...
# 1000             250 2020-01-05 02:22:42.162162162         1095         533
# 1001             412 2020-01-07 11:27:34.054054054         1008         542
# 1002             816 2020-01-06 02:48:38.918918918         1060         511
# 1003             702 2020-01-09 08:38:55.135135135         1054         504
# 1004               4 2020-01-03 10:22:42.162162162         1018         545
#
#       Quantity  Unit_Price   Total_Cost  Discount_Rate Sales_Channel  \
# 0            3  120.436821  8265.374549           0.20        Online
# 1            6  475.724994  4047.850479           0.00      Reseller
# 2            3  146.400556  5096.553818           0.05        Direct
# 3            6   19.373194  8194.281993           0.00      Reseller
# 4            8  193.221313  8331.329249           0.20        Direct
# ...        ...         ...          ...            ...           ...
# 1000         5  490.760429  1138.724711           0.00      Reseller
# 1001         9  236.240910  1786.865600           0.10        Online
# 1002         6  256.467791  6443.682500           0.20       Partner
# 1003         6  256.467791  4814.744796           0.00        Online
# 1004         2  248.937627  1971.790456           0.20        Direct
#
#      Order_Priority  ...  Return_Reason   Payment_Type Taxable Region  \
# 0              High  ...     Wrong Item  Wire Transfer   False   West
# 1          Critical  ...        Damaged         PayPal    True  South
# 2          Critical  ...        Damaged         PayPal    True   West
# 3            Medium  ...     Wrong Item           Cash    True  South
# 4               Low  ...           Late           Cash   False  South
# ...             ...  ...            ...            ...     ...    ...
# 1000         Medium  ...        Damaged    Credit Card    True  South
# 1001         Medium  ...  Not Specified           Cash    True  South
# 1002         Medium  ...  Not Specified           Cash   False   West
# 1003         Medium  ...        Damaged           Cash    True   West
# 1004            Low  ...  Not Specified           Cash    True   East
#
#       Country Customer_Name   Customer_Phone               Customer_Email  \
# 0      Canada  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1      Mexico  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2      Canada  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3      Canada  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4      Mexico  Customer 484  +1-986-360-9109    customer.484.3@sample.com
# ...       ...           ...              ...                          ...
# 1000   Canada  Customer 250  +1-875-504-2878   customer.250.26@sample.com
# 1001      USA  Customer 412  +1-645-470-5077   customer.412.80@sample.com
# 1002   Mexico  Customer 816  +1-162-396-1771   customer.816.55@sample.com
# 1003   Canada  Customer 702  +1-130-713-1098   customer.702.30@sample.com
# 1004   Canada    Customer 4  +1-756-713-6966     customer.4.99@sample.com
#
#                      Customer_Address Product_List_Title
# 0         275 Second St, Phoenix, USA         Product 53
# 1         478 Third St, New York, USA         Product 33
# 2         843 Second St, Phoenix, USA          Product 6
# 3           153 Main St, Phoenix, USA         Product 68
# 4        264 Second St, New York, USA         Product 89
# ...                               ...                ...
# 1000        664 Main St, Chicago, USA         Product 16
# 1001       699 Third St, Houston, USA         Product 38
# 1002  453 Fourth St, Los Angeles, USA         Product 48
# 1003      438 Fourth St, Houston, USA         Product 38
# 1004       383 Park Ave, Houston, USA         Product 16
#
# [1005 rows x 25 columns]

# %%
# Create the Customers Table

Customers = ZikoDF[['Customer_ID' ,'Customer_Name', 'Customer_Phone', 'Customer_Email', 'Customer_Address']].copy().drop_duplicates().reset_index(drop=True)

Customers
# Out:
#      Customer_ID Customer_Name   Customer_Phone               Customer_Email  \
# 0           1086  Customer 200  +1-652-572-9306  customer.200.78@example.com
# 1           1078  Customer 321  +1-311-186-5760   customer.321.13@sample.com
# 2           1077  Customer 989  +1-922-606-9032  customer.989.99@example.com
# 3           1027  Customer 682  +1-237-853-5808     customer.682.66@demo.com
# 4           1052  Customer 484  +1-986-360-9109    customer.484.3@sample.com
# ..           ...           ...              ...                          ...
# 995         1095  Customer 250  +1-875-504-2878   customer.250.26@sample.com
# 996         1008  Customer 412  +1-645-470-5077   customer.412.80@sample.com
# 997         1060  Customer 816  +1-162-396-1771   customer.816.55@sample.com
# 998         1054  Customer 702  +1-130-713-1098   customer.702.30@sample.com
# 999         1018    Customer 4  +1-756-713-6966     customer.4.99@sample.com
#
#                     Customer_Address
# 0        275 Second St, Phoenix, USA
# 1        478 Third St, New York, USA
# 2        843 Second St, Phoenix, USA
# 3          153 Main St, Phoenix, USA
# 4       264 Second St, New York, USA
# ..                               ...
# 995        664 Main St, Chicago, USA
# 996       699 Third St, Houston, USA
# 997  453 Fourth St, Los Angeles, USA
# 998      438 Fourth St, Houston, USA
# 999       383 Park Ave, Houston, USA
#
# [1000 rows x 5 columns]

# %%
# Create the Products Table

Products = ZikoDF[['Product_ID', 'Product_List_Title', 'Unit_Price']].copy().drop_duplicates().reset_index(drop=True)
Products
# Out:
#      Product_ID Product_List_Title  Unit_Price
# 0           536         Product 53  120.436821
# 1           523         Product 33  475.724994
# 2           535          Product 6  146.400556
# 3           546         Product 68   19.373194
# 4           556         Product 89  193.221313
# ..          ...                ...         ...
# 994         533         Product 16  490.760429
# 995         542         Product 38  236.240910
# 996         511         Product 48  256.467791
# 997         504         Product 38  256.467791
# 998         545         Product 16  248.937627
#
# [999 rows x 3 columns]

# %%
TransactionsFACTS = ZikoDF.merge(Customers, on = ['Customer_ID' ,'Customer_Name', 'Customer_Phone', 'Customer_Email', 'Customer_Address'], how = 'left') \
                          .merge (Products, on = ['Product_ID', 'Product_List_Title', 'Unit_Price'], how = 'left') \
                          [['Transaction_ID', 'Date', 'Customer_ID', 'Product_ID', 'Quantity', 'Total_Cost', 'Discount_Rate', 'Sales_Channel','Order_Priority', \
                            'Warehouse_Code','Ship_Mode', 'Delivery_Status','Customer_Satisfaction', 'Item_Returned', 'Return_Reason','Payment_Type', 'Taxable', \
                            'Region', 'Country']]

# %%
TransactionsFACTS
# Out:
#       Transaction_ID                          Date  Customer_ID  Product_ID  \
# 0                200 2020-01-01 20:32:25.945945945         1086         536
# 1                321 2020-01-02 06:55:08.108108108         1078         523
# 2                989 2020-01-06 08:12:58.378378378         1077         535
# 3                682 2020-01-07 22:03:14.594594594         1027         546
# 4                484 2020-01-07 07:08:06.486486486         1052         556
# ...              ...                           ...          ...         ...
# 1000             250 2020-01-05 02:22:42.162162162         1095         533
# 1001             412 2020-01-07 11:27:34.054054054         1008         542
# 1002             816 2020-01-06 02:48:38.918918918         1060         511
# 1003             702 2020-01-09 08:38:55.135135135         1054         504
# 1004               4 2020-01-03 10:22:42.162162162         1018         545
#
#       Quantity   Total_Cost  Discount_Rate Sales_Channel Order_Priority  \
# 0            3  8265.374549           0.20        Online           High
# 1            6  4047.850479           0.00      Reseller       Critical
# 2            3  5096.553818           0.05        Direct       Critical
# 3            6  8194.281993           0.00      Reseller         Medium
# 4            8  8331.329249           0.20        Direct            Low
# ...        ...          ...            ...           ...            ...
# 1000         5  1138.724711           0.00      Reseller         Medium
# 1001         9  1786.865600           0.10        Online         Medium
# 1002         6  6443.682500           0.20       Partner         Medium
# 1003         6  4814.744796           0.00        Online         Medium
# 1004         2  1971.790456           0.20        Direct            Low
#
#      Warehouse_Code  Ship_Mode Delivery_Status Customer_Satisfaction  \
# 0              WH-3      2-Day       Cancelled               Neutral
# 1              WH-1  Overnight       Backorder             Satisfied
# 2              WH-1  Overnight         Pending           Unsatisfied
# 3              WH-1    Express         Pending           Unsatisfied
# 4              WH-2      2-Day       Delivered             Satisfied
# ...             ...        ...             ...                   ...
# 1000           WH-3    Express       Delivered           Unsatisfied
# 1001           WH-3      2-Day       Cancelled               Neutral
# 1002           WH-3      2-Day       Cancelled           Unsatisfied
# 1003           WH-2    Regular       Cancelled             Satisfied
# 1004           WH-1      2-Day       Backorder           Unsatisfied
#
#       Item_Returned  Return_Reason   Payment_Type  Taxable Region Country
# 0             False     Wrong Item  Wire Transfer    False   West  Canada
# 1              True        Damaged         PayPal     True  South  Mexico
# 2              True        Damaged         PayPal     True   West  Canada
# 3             False     Wrong Item           Cash     True  South  Canada
# 4              True           Late           Cash    False  South  Mexico
# ...             ...            ...            ...      ...    ...     ...
# 1000           True        Damaged    Credit Card     True  South  Canada
# 1001           True  Not Specified           Cash     True  South     USA
# 1002           True  Not Specified           Cash    False   West  Mexico
# 1003          False        Damaged           Cash     True   West  Canada
# 1004           True  Not Specified           Cash     True   East  Canada
#
# [1005 rows x 19 columns]

# %%
TransactionsFACTS['Date'] = TransactionsFACTS['Date'].astype('datetime64[us]')

# %%
# Creating CSV Files for Temp Loading
Customers.to_csv(r'Datasets/Customers.csv', index =False)
Products.to_csv(r'Datasets/Products.csv', index =False)
TransactionsFACTS.to_csv(r'Datasets/TransactionsFACTS.csv', index =False)

# %%
# Data Loading to Azure
# Setup Azure Blob Connection 

# Call  the ENV file
load_dotenv('Ziklogistic.env', override=True)

connect_str = os.getenv('Connection_Str') 

blob_service_client = BlobServiceClient.from_connection_string(connect_str)

CNTName = os.getenv('Container_Name')

CNTClient = blob_service_client.get_container_client(CNTName)

# %%
# Creating a function for Data Loading into Azure

def Upld (df, CNT_Client, blobNAME): 
    buffer =  io.BytesIO()
    df.to_parquet(buffer, index = False)
    buffer.seek(0)
    blob_client = CNT_Client.get_blob_client(blobNAME) 
    blob_client.upload_blob(buffer, blob_type = 'BlockBlob', overwrite = True)
    print(f'{blobNAME} uploaded to Blob Storage Successfully')

# %%
#Upl data as  Parquet to Blob Storage
Upld(Customers, CNTClient, 'rawdata/Customers.parquet') 
Upld(Products, CNTClient, 'rawdata/Products.parquet') 
Upld(TransactionsFACTS, CNTClient, 'rawdata/TransactionsFACTS.parquet')
# Out:
# rawdata/Customers.parquet uploaded to Blob Storage Successfully
# rawdata/Products.parquet uploaded to Blob Storage Successfully
# rawdata/TransactionsFACTS.parquet uploaded to Blob Storage Successfully
